# %%
l1 = [1, 2, 3, 4]
l2 = [5, 6, 7, 8]
l3 = [x for x in "Leonardo"]
l4 = [x for x in "Acarajé"]

t1= zip(l1, l2)
t2= zip(l3, l4)

# %%
list(t1)
# Out:
# [(1, 5), (2, 6), (3, 7), (4, 8)]

# %%
list(t2)
# Out:
# [('L', 'A'),
#  ('e', 'c'),
#  ('o', 'a'),
#  ('n', 'r'),
#  ('a', 'a'),
#  ('r', 'j'),
#  ('d', 'é')]

# %%
d1={"a":1, "b":2}
d2={"c":3, "d":4}

# %%
list(zip(d1, d2))
# Out:
# [('a', 'c'), ('b', 'd')]

# %%
list(zip(d1, d2.values()))
# Out:
# [('a', 3), ('b', 4)]

# %%
def trocar_valores(d1, d2):
    dicio={}
    for d1key, d2val in zip(d1, d2.values()):
        dicio[d1key]=d2val

    return dicio

# %%
trocar_valores(d1,d2)
# Out:
# {'a': 3, 'b': 4}
