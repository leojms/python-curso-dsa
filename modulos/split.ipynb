# %%
letra = input() 

alfabeto = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
alfabeto = alfabeto.split()

for i in range(1, len(alfabeto)+1):
  if letra == alfabeto[i-1]:
    break
  i=i+1

print(i)
# Out:
# F
# 2
