# %%
def operacao(y):
    return y*6

# %%
lista = [0, 4, 3.5, 67]
lista2 = [7, 4, 20, 78]

# %%
list(map(operacao, lista))
# Out:
# [0, 24, 21.0, 402]

# %%
list(map(lambda y: y*6, lista))
# Out:
# [0, 24, 21.0, 402]

# %%
list(map(lambda x, y: x+2*y, lista, lista2))
# Out:
# [14, 12, 43.5, 223]
