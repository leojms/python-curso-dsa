# %%
import numpy as np

x = np.random.rand(10)
x
# Out:
# array([0.52103842, 0.61404068, 0.66817065, 0.92618218, 0.73218136,
#        0.34453087, 0.7977081 , 0.94259028, 0.45838585, 0.81952546])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.show((plt.hist(np.random.rand(1000))))

# %%
plt.show((plt.hist(np.random.randn(1000))))

# %%
img = np.random.rand(300,300)
plt.imshow(img, cmap = plt.cm.hot)
plt.colorbar()

# %%
y = np.random.rand(10)
y
# Out:
# array([0.0517688 , 0.2024687 , 0.62799942, 0.79907396, 0.94102143,
#        0.15816132, 0.03930508, 0.5296329 , 0.19291941, 0.70843043])

# %%
np.mean(y)
# Out:
# 0.42507814356372436

# %%
np.std(y)
# Out:
# 0.3164404458610296

# %%
np.var(y)
# Out:
# 0.10013455577672721

# %%
z=np.arange(1,10)
np.sum(z)
# Out:
# 45
