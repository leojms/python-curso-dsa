# %%
import pandas as pd

# %%
obj = pd.Series([66, 56, 8, 90])
obj
# Out:
# 0    66
# 1    56
# 2     8
# 3    90
# dtype: int64

# %%
obj.values
# Out:
# array([66, 56,  8, 90])

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj2 = pd.Series([66, 536, 80, 9], index=["a", "b", "c", "d"])
obj2
# Out:
# a     66
# b    536
# c     80
# d      9
# dtype: int64

# %%
obj2[obj2>60]
# Out:
# a     66
# b    536
# c     80
# dtype: int64

# %%
obj2["b"]
# Out:
# 536

# %%
"d" in obj2
# Out:
# True

# %%
dicio={'arroz': 40, 'feijao': 3, 'batata': 80, 'frango': 9}
obj3=pd.Series(dicio)
obj3
# Out:
# arroz     40
# feijao     3
# batata    80
# frango     9
# dtype: int64

# %%
comida = ['arroz', 'feijao', 'batata', 'carne']
obj4=pd.Series(dicio, index=comida)
obj4
# Out:
# arroz     40.0
# feijao     3.0
# batata    80.0
# carne      NaN
# dtype: float64

# %%
pd.isnull(obj4)
# Out:
# arroz     False
# feijao    False
# batata    False
# carne      True
# dtype: bool

# %%
pd.notnull(obj4)
# Out:
# arroz      True
# feijao     True
# batata     True
# carne     False
# dtype: bool

# %%
obj4.isnull()
# Out:
# arroz     False
# feijao    False
# batata    False
# carne      True
# dtype: bool

# %%
obj3+obj4
# Out:
# arroz      80.0
# batata    160.0
# carne       NaN
# feijao      6.0
# frango      NaN
# dtype: float64

# %%
obj4.name= 'preço da comida'
obj4.index.name = 'comida'
obj4
# Out:
# comida
# arroz     40.0
# feijao     3.0
# batata    80.0
# carne      NaN
# Name: preço da comida, dtype: float64
