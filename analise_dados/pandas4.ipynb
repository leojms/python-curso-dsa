# %%
import pandas as pd
import numpy as np

# %%
rng = pd.date_range('1/1/2018', periods=50, freq = 'S')

# %%
ts=pd.Series(np.random.randint(0,500,len(rng)), index = rng)
ts
# Out:
# 2018-01-01 00:00:00    459
# 2018-01-01 00:00:01    430
# 2018-01-01 00:00:02    347
# 2018-01-01 00:00:03    301
# 2018-01-01 00:00:04    216
# 2018-01-01 00:00:05    430
# 2018-01-01 00:00:06      1
# 2018-01-01 00:00:07    169
# 2018-01-01 00:00:08    127
# 2018-01-01 00:00:09    115
# 2018-01-01 00:00:10    181
# 2018-01-01 00:00:11    372
# 2018-01-01 00:00:12    219
# 2018-01-01 00:00:13    398
# 2018-01-01 00:00:14    128
# 2018-01-01 00:00:15    106
# 2018-01-01 00:00:16      9
# 2018-01-01 00:00:17     73
# 2018-01-01 00:00:18    262
# 2018-01-01 00:00:19    206
# 2018-01-01 00:00:20     52
# 2018-01-01 00:00:21    441
# 2018-01-01 00:00:22    196
# 2018-01-01 00:00:23    259
# 2018-01-01 00:00:24    462
# 2018-01-01 00:00:25    151
# 2018-01-01 00:00:26    373
# 2018-01-01 00:00:27    278
# 2018-01-01 00:00:28    195
# 2018-01-01 00:00:29    429
# 2018-01-01 00:00:30    482
# 2018-01-01 00:00:31     96
# 2018-01-01 00:00:32    107
# 2018-01-01 00:00:33     45
# ...

# %%
rng = pd.date_range('1/1/2016', periods=5, freq = 'M')
ts=pd.Series(np.random.randn(len(rng)), index = rng)
ts
# Out:
# 2016-01-31   -0.959671
# 2016-02-29    0.784741
# 2016-03-31   -0.696696
# 2016-04-30   -0.157555
# 2016-05-31    1.418705
# Freq: M, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
ts=pd.Series(np.random.randn(500), index = pd.date_range('1/1/2016', periods=500))
ts=ts.cumsum()
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(500,4), index=ts.index, columns=list("ABCD"))
df = df.cumsum()
df.plot()

# %%
import os

# %%
# !type /content/drive/MyDrive/teste.xlsx
# Out:
# /bin/bash: line 0: type: /content/drive/MyDrive/teste.xlsx: not found

# %%
df.to_excel('teste.xlsx', sheet_name="Dataframe")

# %%
df2 = pd.read_excel('teste.xlsx', "Dataframe", index_col=None, na_values="NA")
df2
# Out:
#     Unnamed: 0          A          B          C          D
# 0   2016-01-01   0.483229  -1.214291   0.757326  -0.000390
# 1   2016-01-02  -0.750911  -2.774856   0.810437   0.037878
# 2   2016-01-03  -0.588665  -2.821262  -1.943343  -0.702489
# 3   2016-01-04  -0.733836  -2.863837  -2.756367  -2.171844
# 4   2016-01-05  -0.612369  -2.502716  -2.552836  -2.114960
# ..         ...        ...        ...        ...        ...
# 495 2017-05-10 -24.994067 -18.641116  33.302181 -28.429083
# 496 2017-05-11 -24.443074 -17.952200  35.369413 -29.728173
# 497 2017-05-12 -22.611216 -16.842834  35.659645 -29.270254
# 498 2017-05-13 -21.713567 -17.078858  36.048067 -28.055490
# 499 2017-05-14 -22.785794 -15.483183  36.176256 -28.264074
#
# [500 rows x 5 columns]

# %%
os.remove('teste.xlsx')
