# %%
import pandas as pd

# %%
data = {"Estado": ["Bahia", "Santa Catarina", "Pernambuco", "Paraiba"], 
        "Ano": [2000, 2001, 2002, 2003],
        "População": [1.4, 2, 1.3, 1.2]}

# %%
df=pd.DataFrame(data)
df
# Out:
#            Estado   Ano  População
# 0           Bahia  2000        1.4
# 1  Santa Catarina  2001        2.0
# 2      Pernambuco  2002        1.3
# 3         Paraiba  2003        1.2

# %%
pd.DataFrame(df, columns = ["Estado", "Ano", "População"])
# Out:
#            Estado   Ano  População
# 0           Bahia  2000        1.4
# 1  Santa Catarina  2001        2.0
# 2      Pernambuco  2002        1.3
# 3         Paraiba  2003        1.2

# %%
df2 = pd.DataFrame(df, columns = ["Estado", "Ano", "População", "Débito"], index=[1,2,3,4,5])
df2
# Out:
#            Estado     Ano  População  Débito
# 1  Santa Catarina  2001.0        2.0     NaN
# 2      Pernambuco  2002.0        1.3     NaN
# 3         Paraiba  2003.0        1.2     NaN
# 4             NaN     NaN        NaN     NaN
# 5             NaN     NaN        NaN     NaN

# %%
df2["Estado"]
# Out:
# 1    Santa Catarina
# 2        Pernambuco
# 3           Paraiba
# 4               NaN
# 5               NaN
# Name: Estado, dtype: object

# %%
df2.index
# Out:
# Int64Index([1, 2, 3, 4, 5], dtype='int64')

# %%
df2.columns
# Out:
# Index(['Estado', 'Ano', 'População', 'Débito'], dtype='object')

# %%
df2.values
# Out:
# array([['Santa Catarina', 2001.0, 2.0, nan],
#        ['Pernambuco', 2002.0, 1.3, nan],
#        ['Paraiba', 2003.0, 1.2, nan],
#        [nan, nan, nan, nan],
#        [nan, nan, nan, nan]], dtype=object)

# %%
df2.Estado
# Out:
# 1    Santa Catarina
# 2        Pernambuco
# 3           Paraiba
# 4               NaN
# 5               NaN
# Name: Estado, dtype: object

# %%
df2[:2]
# Out:
#            Estado     Ano  População  Débito
# 1  Santa Catarina  2001.0        2.0     NaN
# 2      Pernambuco  2002.0        1.3     NaN

# %%
df3 = pd.DataFrame(df, columns = ["Estado", "Ano", "População", "Débito"])
df3
# Out:
#            Estado   Ano  População  Débito
# 0           Bahia  2000        1.4     NaN
# 1  Santa Catarina  2001        2.0     NaN
# 2      Pernambuco  2002        1.3     NaN
# 3         Paraiba  2003        1.2     NaN

# %%
import numpy as np

# %%
df3["Débito"] = np.arange(4.)
df3
# Out:
#            Estado   Ano  População  Débito
# 0           Bahia  2000        1.4     0.0
# 1  Santa Catarina  2001        2.0     1.0
# 2      Pernambuco  2002        1.3     2.0
# 3         Paraiba  2003        1.2     3.0

# %%
df3.describe()
# Out:
#                Ano  População    Débito
# count     4.000000   4.000000  4.000000
# mean   2001.500000   1.475000  1.500000
# std       1.290994   0.359398  1.290994
# min    2000.000000   1.200000  0.000000
# 25%    2000.750000   1.275000  0.750000
# 50%    2001.500000   1.350000  1.500000
# 75%    2002.250000   1.550000  2.250000
# max    2003.000000   2.000000  3.000000

# %%
df3[2:4]
# Out:
#        Estado   Ano  População  Débito
# 2  Pernambuco  2002        1.3     2.0
# 3     Paraiba  2003        1.2     3.0

# %%
df3.iloc[2]
# Out:
# Estado       Pernambuco
# Ano                2002
# População           1.3
# Débito              2.0
# Name: 2, dtype: object
